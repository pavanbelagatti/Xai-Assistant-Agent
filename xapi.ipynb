# %% [markdown]
# ## Build with Grok - using the xAI API
# This code effectively sets up an AI-powered writing assistant that can analyze a specific writing style and produce text that mimics that style when given prompts. It utilizes Grok's API through OpenAI's interface to achieve this functionality.

# %% [markdown]
# ### Installing the OpenAI library

# %%
# !pip install openai --quiet

# %%
import os
import openai

# %% [markdown]
# ### Function: create_style_assistant
# This function initializes the OpenAI client with a specified API key and constructs a system message that instructs the AI to analyze a given writing example and replicate its style in future responses.
#
# ### Function: generate_response
# This function generates a response from the AI based on the provided prompt while maintaining the specified writing style.
#
# ### Main Execution Block
# This block serves as the entry point for executing the script.

# %%
import os
from openai import OpenAI

def create_style_assistant(writing_example):
    XAI_API_KEY = "Add Your xAI API Key"
    client = OpenAI(
        api_key=XAI_API_KEY,
        base_url="https://api.x.ai/v1",
    )
    system_message = f"""Analyze this writing example 
    and mimic its style,
     tone, and voice in your responses: {writing_example} 
     Maintain this same
      writing style in all your responses."""

    return client, system_message

def generate_response(client, system_message, prompt):
    completion = client.chat.completions.create(
        model="grok-beta",
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": prompt},
        ]
    )

    return completion.choices[0].message.content

if __name__ == "__main__":
    my_writing_style = """In today's digital age, having a strong online presence is crucial for both individuals and businesses. With the right approach, you can leverage social media to connect with like-minded professionals, showcase your skills, and even attract new opportunities. Consistency, authenticity, and understanding your audience are key components of successful online branding. For instance, when creating content, it's essential to provide value and engage meaningfully with your audience. Whether you're sharing insights, highlighting achievements, or discussing industry trends, aim to offer content that resonates and adds value. Remember: people connect with people, so being relatable and genuine will set you apart in the digital landscape."""

    # Create the assistant
    client, system_message = create_style_assistant(my_writing_style)

    # Generate a response
    prompt = f"""Write a post about this news: A leading tech company has just announced the launch of an innovative AI tool that enhances online interactions by personalizing user experiences and streamlining communication. This tool uses advanced machine learning algorithms to analyze user behavior and preferences, aiming to create more meaningful connections in digital spaces."""
    response = generate_response(client, system_message, prompt)
    print(response)
# Out:
# In an era where online interactions are becoming increasingly central to our daily lives, a pioneering tech company has just unveiled a game-changer. Imagine a tool that not only understands your digital habits but also tailors your online experience to fit you like a glove. This is precisely what this new AI tool promises to deliver.
#
# With the launch of this innovative AI, the company is setting a new standard for personalized online engagement. Here's what makes this tool stand out:
#
# **Personalization at Its Finest:** By harnessing the power of advanced machine learning, this AI tool dives deep into your behavior and preferences. It's like having a digital concierge who knows what you like, anticipates your needs, and crafts your online journey accordingly.
#
# **Streamlining Communication:** We've all experienced the frustration of sifting through endless emails or navigating through cluttered social media feeds. This AI tool aims to cut through the noise, making communication more efficient and, importantly, more meaningful.
#
# **Creating Meaningful Connections:** In today's digital landscape, where connections can often feel superficial, this tool seeks to foster genuine relationships. It does this by providing content and interactions that resonate on a personal level, ensuring that every digital encounter feels authentic and relevant.
#
# **Why It Matters:** In a world where authenticity and understanding your audience are key, this AI tool represents a significant leap forward. It's not just about technology; it's about using technology to enhance human connections, making our online spaces more reflective of our true selves.
#
# This launch signifies more than just a new product; it's a testament to the evolving nature of how we interact online. By focusing on personalization, efficiency, and meaningful engagement, this AI tool is poised to redefine our digital experiences. Whether you're looking to connect with like-minded professionals, share your insights, or simply navigate the digital world with ease, this tool is set to make your online presence not just stronger, but also more authentic and engaging. Remember: in the digital age, it's not just about being seen, but about being understood.

# %%
import os
from openai import OpenAI

def create_client():
    XAI_API_KEY = "Add Your xAI API Key"
    client = OpenAI(
        api_key=XAI_API_KEY,
        base_url="https://api.x.ai/v1",
    )
    return client

def generate_response(client, system_message, prompt):
    completion = client.chat.completions.create(
        model="grok-beta",
        messages=[
            {"role": "system", "content": system_message},
            {"role": "user", "content": prompt},
        ]
    )
    return completion.choices[0].message.content

def summarize_text(client, text):
    prompt = f"Summarize the following text:\n\n{text}"
    return generate_response(client, "", prompt)

def analyze_sentiment(client, text):
    prompt = f"Analyze the sentiment of the following text:\n\n{text}"
    return generate_response(client, "", prompt)

def extract_topics(client, text):
    prompt = f"Extract the key topics from the following text:\n\n{text}"
    return generate_response(client, "", prompt)

if __name__ == "__main__":
    my_writing_style = """In today's digital age, having a strong online presence is crucial for both individuals and businesses. With the right approach, you can leverage social media to connect with like-minded professionals, showcase your skills, and even attract new opportunities. Consistency, authenticity, and understanding your audience are key components of successful online branding. For instance, when creating content, it's essential to provide value and engage meaningfully with your audience. Whether you're sharing insights, highlighting achievements, or discussing industry trends, aim to offer content that resonates and adds value. Remember: people connect with people, so being relatable and genuine will set you apart in the digital landscape."""

    # Create the assistant
    client = create_client()
    system_message = f"Analyze this writing example and mimic its style, tone, and voice: {my_writing_style}"

    # Generate a response
    prompt = "Write a post about this news: A leading tech company has just announced the launch of an innovative AI tool that enhances online interactions by personalizing user experiences and streamlining communication. This tool uses advanced machine learning algorithms to analyze user behavior and preferences, aiming to create more meaningful connections in digital spaces."
    response = generate_response(client, system_message, prompt)
    print("Generated Response:", response)

    # Summarize the response
    summary = summarize_text(client, response)
    print("Summary:", summary)

    # Analyze sentiment
    sentiment = analyze_sentiment(client, response)
    print("Sentiment Analysis:", sentiment)

    # Extract topics
    topics = extract_topics(client, response)
    print("Extracted Topics:", topics)
# Out:
# Generated Response: In today's interconnected world, staying ahead of the digital curve is not just an option; it's a necessity. Enter the latest innovation from a leading tech giant, which promises to redefine our online interactions. They've just unveiled a groundbreaking AI tool designed to revolutionize how we connect, communicate, and engage in digital spaces.
#
# Imagine an online experience where every click, swipe, or message feels tailored just for you. This new tool harnesses the power of advanced machine learning algorithms to analyze your behavior and preferences, crafting personalized experiences that resonate on a deeper level. Whether you're a business looking to foster customer loyalty, a content creator aiming to captivate your audience, or simply someone wanting to make more meaningful connections, this AI tool is set to streamline communication like never before.
#
# Here’s why this is a game-changer:
#
# - **Personalization**: The AI doesn't just serve content; it curates an experience that feels uniquely yours. It understands what you like, how you interact, and even anticipates your needs.
#
# - **Streamlined Communication**: Say goodbye to the clutter. This tool filters out the noise, ensuring that your interactions are more efficient and purposeful.
#
# - **Engagement**: By providing content that aligns with your interests, it encourages more engagement, making every digital touchpoint count.
#
# - **Business Growth**: For companies, this means higher conversion rates, increased user satisfaction, and a brand experience that stands out in the crowded digital marketplace.
#
# The implications are vast. For individuals, this tool can transform casual browsing into a journey of discovery, connecting you with communities and content that truly matter. For businesses, it's about building relationships, not just transactions.
#
# In an era where authenticity and value are the currency of engagement, this AI tool stands as a beacon of how technology can enhance, rather than detract from, the human experience. By focusing on understanding your audience, delivering consistency, and providing genuine, value-driven content, this tech company is setting a new standard in digital interaction.
#
# Remember: in the vast digital landscape, it's the meaningful connections that endure. With tools like this, we're not just navigating the digital world; we're shaping it to fit our aspirations and desires. Keep an eye out for this innovation, as it might just change the way you think about your online presence.
# Summary: The text discusses a new AI tool introduced by a leading tech company, designed to enhance digital interactions by personalizing online experiences. Here are the key points:
#
# - **Purpose**: The AI tool aims to transform how we connect, communicate, and engage online by using advanced machine learning to analyze user behavior and preferences.
#
# - **Benefits**:
#   - **Personalization**: Tailors content and experiences to individual users.
#   - **Streamlined Communication**: Reduces digital clutter, making interactions more efficient.
#   - **Engagement**: Increases user engagement by aligning content with user interests.
#   - **Business Growth**: Enhances customer loyalty, conversion rates, and overall user satisfaction for businesses.
#
# - **Implications**:
#   - For individuals, it promises a more meaningful and engaging online experience.
#   - For businesses, it shifts the focus from transactions to building lasting relationships.
#
# - **Overall Impact**: The tool sets a new benchmark in digital interaction by emphasizing authenticity, value, and tailored experiences, potentially reshaping the digital landscape to better fit user desires and expectations.
# Sentiment Analysis: The sentiment of the provided text is overwhelmingly **positive**. Here are some key points that contribute to this sentiment:
#
# 1. **Optimism and Excitement**: The text expresses excitement about the future of digital interaction with phrases like "revolutionize how we connect," "game-changer," and "transform casual browsing into a journey of discovery." These phrases convey a sense of optimism about technological advancements.
#
# 2. **Innovation and Advancement**: The mention of "latest innovation" and "groundbreaking AI tool" highlights a positive view towards technological progress and its potential benefits.
#
# 3. **Benefits Highlighted**: The text lists numerous benefits such as personalization, streamlined communication, increased engagement, and business growth, all of which are framed positively.
#
# 4. **Human Enhancement**: The narrative focuses on how technology can "enhance, rather than detract from, the human experience," which suggests a hopeful, positive integration of technology into everyday life.
#
# 5. **Encouragement**: Phrases like "Keep an eye out for this innovation" encourage the reader to look forward to and embrace this new technology.
#
# 6. **Aspirational Tone**: The language used, such as "shaping it to fit our aspirations and desires," imbues a sense of ambition and positivity about what can be achieved with this new tool.
#
# 7. **Lack of Criticism**: There is no mention of drawbacks, potential misuse, or negative aspects, which keeps the sentiment purely positive.
#
# Overall, the text paints a picture of a future where digital interactions are improved for both individuals and businesses, fostering a sense of anticipation and approval for the new AI tool.
# Extracted Topics: Here are the key topics extracted from the provided text:
#
# 1. **Digital Innovation**: Discussion on the necessity of staying ahead in the digital world.
#
# 2. **AI Technology**: Introduction of a new AI tool by a tech giant aimed at revolutionizing online interactions.
#
# 3. **Personalization**:
#    - How the AI tool personalizes user experiences through machine learning algorithms.
#    - Tailored content and interactions based on user behavior and preferences.
#
# 4. **Streamlined Communication**:
#    - Filtering out irrelevant content to make interactions more efficient.
#
# 5. **User Engagement**:
#    - Increasing engagement by aligning content with user interests.
#
# 6. **Business Implications**:
#    - Benefits for businesses including higher conversion rates, user satisfaction, and brand differentiation.
#
# 7. **Authenticity and Value**:
#    - Emphasis on genuine, value-driven content in the digital space.
#
# 8. **Relationship Building**:
#    - Focus on fostering meaningful connections rather than mere transactions.
#
# 9. **Impact on Individuals and Businesses**:
#    - Enhancing casual browsing into meaningful discovery for individuals.
#    - For businesses, it's about enhancing customer relationships.
#
# 10. **Setting New Standards**:
#     - The tool as a benchmark for future digital interactions.
#
# 11. **Future of Digital Interaction**:
#     - How this tool might reshape our online presence and interactions.
